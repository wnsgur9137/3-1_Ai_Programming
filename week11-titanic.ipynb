# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# 데이터 세트를 읽어들인다. 
train = pd.read_csv("./dataset/train.csv", sep=',')
test = pd.read_csv("./dataset/test.csv", sep=',')

# 필요없는 컬럼을 삭제한다. 
train.drop(['SibSp', 'Parch', 'Ticket', 'Embarked', 'Name',\
        'Cabin', 'PassengerId', 'Fare', 'Age'], inplace=True, axis=1)
test.drop(['SibSp', 'Parch', 'Ticket', 'Embarked', 'Name',\
        'Cabin', 'PassengerId', 'Fare', 'Age'], inplace=True, axis=1)

# 결손치가 있는 데이터 행은 삭제한다. 
train.dropna(inplace=True)
test.dropna(inplace=True)

# 기호를 수치로 변환한다. 
for ix in train.index:
    if train.loc[ix, 'Sex']=="male":
       train.loc[ix, 'Sex']=1 
    else:
       train.loc[ix, 'Sex']=0 
for ix in test.index:
    if test.loc[ix, 'Sex']=="male":
       test.loc[ix, 'Sex']=1 
    else:
       test.loc[ix, 'Sex']=0 


# 2차원 배열을 1차원 배열로 평탄화한다. 
target = np.ravel(train.Survived) 


# 생존여부를 학습 데이터에서 삭제한다. 
train.drop(['Survived'], inplace=True, axis=1)
train = train.astype(float)     # 최근 소스에서는 float형태로 형변환하여야 
test = test.astype(float)     # 최근 소스에서는 float형태로 형변환하여야 



# 케라스 모델을 생성한다. 
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# 케라스 모델을 컴파일한다. 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# 케라스 모델을 학습시킨다. 
model.fit(train, target, epochs=30, batch_size=1, verbose=1)
print('모델1')
model.summary()


print('\n', '-'*20, sep='')
print('-'*20)
print('-'*20, '\n', sep='')


# 두 번째 케라스 모델을 생성한다. 
model2 = tf.keras.models.Sequential()
model2.add(tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)))
model2.add(tf.keras.layers.Dense(16, activation='relu'))
model2.add(tf.keras.layers.Dense(8, activation='relu'))
model2.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# 케라스 모델을 컴파일한다. 
model2.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# 케라스 모델을 학습시킨다. 
model2.fit(train, target, epochs=30, batch_size=1, verbose=1)
print('모델2')
model2.summary()
# Out:
# Epoch 1/30
# 891/891 [==============================] - 1s 652us/step - loss: 0.5836 - accuracy: 0.6745
# Epoch 2/30
# 891/891 [==============================] - 1s 650us/step - loss: 0.5106 - accuracy: 0.7856
# Epoch 3/30
# 891/891 [==============================] - 1s 661us/step - loss: 0.4929 - accuracy: 0.7868
# Epoch 4/30
# 891/891 [==============================] - 1s 711us/step - loss: 0.4831 - accuracy: 0.7868
# Epoch 5/30
# 891/891 [==============================] - 1s 656us/step - loss: 0.4771 - accuracy: 0.7856
# Epoch 6/30
# 891/891 [==============================] - 1s 629us/step - loss: 0.4711 - accuracy: 0.7845
# Epoch 7/30
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4634 - accuracy: 0.7901
# Epoch 8/30
# 891/891 [==============================] - 1s 2ms/step - loss: 0.4668 - accuracy: 0.7778
# Epoch 9/30
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4627 - accuracy: 0.7778
# Epoch 10/30
# 891/891 [==============================] - 1s 650us/step - loss: 0.4605 - accuracy: 0.7811
# Epoch 11/30
# 891/891 [==============================] - 1s 646us/step - loss: 0.4656 - accuracy: 0.7710
# Epoch 12/30
# 891/891 [==============================] - 1s 678us/step - loss: 0.4582 - accuracy: 0.7901
# Epoch 13/30
# 891/891 [==============================] - 1s 639us/step - loss: 0.4582 - accuracy: 0.7912
# Epoch 14/30
# 891/891 [==============================] - 1s 659us/step - loss: 0.4611 - accuracy: 0.7834
# Epoch 15/30
# 891/891 [==============================] - 1s 656us/step - loss: 0.4586 - accuracy: 0.7789
# Epoch 16/30
# 891/891 [==============================] - 1s 658us/step - loss: 0.4585 - accuracy: 0.7834
# Epoch 17/30
# 891/891 [==============================] - 1s 650us/step - loss: 0.4572 - accuracy: 0.7811
# Epoch 18/30
# 891/891 [==============================] - 1s 649us/step - loss: 0.4610 - accuracy: 0.7733
# Epoch 19/30
# 891/891 [==============================] - 1s 821us/step - loss: 0.4606 - accuracy: 0.7823
# Epoch 20/30
# 891/891 [==============================] - 1s 658us/step - loss: 0.4571 - accuracy: 0.7767
# Epoch 21/30
# 891/891 [==============================] - 1s 635us/step - loss: 0.4561 - accuracy: 0.7879
# Epoch 22/30
# 891/891 [==============================] - 1s 683us/step - loss: 0.4573 - accuracy: 0.7744
# Epoch 23/30
# 891/891 [==============================] - 1s 669us/step - loss: 0.4560 - accuracy: 0.7834
# Epoch 24/30
# 891/891 [==============================] - 1s 661us/step - loss: 0.4597 - accuracy: 0.7755
# Epoch 25/30
# 891/891 [==============================] - 1s 676us/step - loss: 0.4562 - accuracy: 0.7935
# Epoch 26/30
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4557 - accuracy: 0.7890
# Epoch 27/30
# 891/891 [==============================] - 1s 701us/step - loss: 0.4570 - accuracy: 0.7856
# Epoch 28/30
# 891/891 [==============================] - 1s 644us/step - loss: 0.4544 - accuracy: 0.7924
# Epoch 29/30
# 891/891 [==============================] - 1s 629us/step - loss: 0.4580 - accuracy: 0.7778
# Epoch 30/30
# 891/891 [==============================] - 1s 634us/step - loss: 0.4563 - accuracy: 0.7688
# 모델1
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 16)                48
#
#  dense_27 (Dense)            (None, 8)                 136
#
#  dense_28 (Dense)            (None, 8)                 72
#
#  dense_29 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 265
# Trainable params: 265
# Non-trainable params: 0
# _________________________________________________________________
#
# --------------------
# --------------------
# --------------------
#
# Epoch 1/30
# 891/891 [==============================] - 1s 635us/step - loss: 0.5746 - accuracy: 0.7015
# Epoch 2/30
# 891/891 [==============================] - 1s 642us/step - loss: 0.4988 - accuracy: 0.7823
# Epoch 3/30
# 891/891 [==============================] - 1s 645us/step - loss: 0.4826 - accuracy: 0.7868
# Epoch 4/30
# 891/891 [==============================] - 1s 652us/step - loss: 0.4759 - accuracy: 0.7845
# Epoch 5/30
# 891/891 [==============================] - 1s 762us/step - loss: 0.4671 - accuracy: 0.7912
# Epoch 6/30
# 891/891 [==============================] - 1s 790us/step - loss: 0.4584 - accuracy: 0.7868
# Epoch 7/30
# 891/891 [==============================] - 1s 750us/step - loss: 0.4619 - accuracy: 0.8002
# Epoch 8/30
# 891/891 [==============================] - 1s 670us/step - loss: 0.4631 - accuracy: 0.7912
# Epoch 9/30
# 891/891 [==============================] - 1s 669us/step - loss: 0.4619 - accuracy: 0.7845
# Epoch 10/30
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4604 - accuracy: 0.7733
# Epoch 11/30
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4628 - accuracy: 0.7823
# Epoch 12/30
# 891/891 [==============================] - 1s 831us/step - loss: 0.4580 - accuracy: 0.7901
# Epoch 13/30
# 891/891 [==============================] - 1s 710us/step - loss: 0.4557 - accuracy: 0.7935
# Epoch 14/30
# 891/891 [==============================] - 1s 675us/step - loss: 0.4571 - accuracy: 0.7868
# Epoch 15/30
# 891/891 [==============================] - 1s 678us/step - loss: 0.4579 - accuracy: 0.7912
# Epoch 16/30
# 891/891 [==============================] - 1s 759us/step - loss: 0.4548 - accuracy: 0.7868
# Epoch 17/30
# 891/891 [==============================] - 1s 1ms/step - loss: 0.4593 - accuracy: 0.7868
# Epoch 18/30
# 891/891 [==============================] - 1s 804us/step - loss: 0.4564 - accuracy: 0.7778
# Epoch 19/30
# 891/891 [==============================] - 1s 771us/step - loss: 0.4579 - accuracy: 0.7811
# Epoch 20/30
# 891/891 [==============================] - 1s 873us/step - loss: 0.4573 - accuracy: 0.7778
# Epoch 21/30
# 891/891 [==============================] - 1s 742us/step - loss: 0.4586 - accuracy: 0.7755
# Epoch 22/30
# 891/891 [==============================] - 1s 884us/step - loss: 0.4574 - accuracy: 0.7767
# Epoch 23/30
# 891/891 [==============================] - 1s 819us/step - loss: 0.4581 - accuracy: 0.7789
# Epoch 24/30
# 891/891 [==============================] - 1s 693us/step - loss: 0.4538 - accuracy: 0.7901
# Epoch 25/30
# 891/891 [==============================] - 1s 699us/step - loss: 0.4567 - accuracy: 0.7935
# Epoch 26/30
# 891/891 [==============================] - 1s 726us/step - loss: 0.4566 - accuracy: 0.7811
# Epoch 27/30
# 891/891 [==============================] - 1s 688us/step - loss: 0.4590 - accuracy: 0.7856
# Epoch 28/30
# 891/891 [==============================] - 1s 692us/step - loss: 0.4569 - accuracy: 0.7778
# Epoch 29/30
# 891/891 [==============================] - 1s 781us/step - loss: 0.4576 - accuracy: 0.7811
# Epoch 30/30
# 891/891 [==============================] - 1s 690us/step - loss: 0.4531 - accuracy: 0.7912
# 모델2
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 16)                48
#
#  dense_31 (Dense)            (None, 16)                272
#
#  dense_32 (Dense)            (None, 8)                 136
#
#  dense_33 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 465
# Trainable params: 465
# Non-trainable params: 0
# _________________________________________________________________
